# %% [markdown]
# # The Data Source Bank
# ------

# %%
# Imports and file upload
import pandas as pd
import numpy as np

df = pd.read_csv("/content/PD 2023 Wk 1 Input.csv")

# %% [markdown]
# ## Initial exploration
# -----

# %%
df.head()
# Out:
#   Transaction Code  Value  Customer Code  Online or In-Person  \
# 0  DTB-716-679-576   1448         100001                    2
# 1   DS-795-814-303   7839         100001                    2
# 2  DSB-807-592-406   5520         100005                    1
# 3   DS-367-545-264   7957         100007                    2
# 4  DSB-474-374-857   5375         100000                    2
#
#       Transaction Date
# 0  20/03/2023 00:00:00
# 1  15/11/2023 00:00:00
# 2  14/07/2023 00:00:00
# 3  18/08/2023 00:00:00
# 4  26/08/2023 00:00:00

# %%
df.shape
# Out:
# (365, 5)

# %%
df.describe()
# Out:
#              Value  Customer Code  Online or In-Person
# count   365.000000     365.000000           365.000000
# mean   4938.813699  100004.961644             1.528767
# std    2940.973461       3.277237             0.499857
# min      13.000000  100000.000000             1.000000
# 25%    2321.000000  100002.000000             1.000000
# 50%    4743.000000  100005.000000             2.000000
# 75%    7427.000000  100008.000000             2.000000
# max    9967.000000  100010.000000             2.000000

# %% [markdown]
# Notes:
# - 365 records and 5 columns in this CSV
# - Avg transaction value 4938, 200 more than median
# - Standard deviation is quite large
# - Not all bank codes are the same length
# - Online / in person is discrete not continuous

# %%
df.dtypes
# Out:
# Transaction Code       object
# Value                   int64
# Customer Code           int64
# Online or In-Person     int64
# Transaction Date       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Transaction Code       0
# Value                  0
# Customer Code          0
# Online or In-Person    0
# Transaction Date       0
# dtype: int64

# %% [markdown]
# ## Task 1: Split transaction Code
# -----
# - Split the Transaction Code to extract the letters at the start of the transaction code. These identify the bank who processes the transaction
# - Rename the new field with the Bank code 'Bank'

# %%
newcols = df['Transaction Code'].str.split("-", n=1, expand=True)
newcols
# Out:
#        0            1
# 0    DTB  716-679-576
# 1     DS  795-814-303
# 2    DSB  807-592-406
# 3     DS  367-545-264
# 4    DSB  474-374-857
# ..   ...          ...
# 360  DTB  116-439-102
# 361   DS  849-981-514
# 362   DS  726-686-279
# 363   DS  551-937-380
# 364   DS  976-542-770
#
# [365 rows x 2 columns]

# %%
df["Bank"] = newcols[0]
df["Transaction Code"] = newcols[1]
df
# Out:
#     Transaction Code  Value  Customer Code  Online or In-Person  \
# 0        716-679-576   1448         100001                    2
# 1        795-814-303   7839         100001                    2
# 2        807-592-406   5520         100005                    1
# 3        367-545-264   7957         100007                    2
# 4        474-374-857   5375         100000                    2
# ..               ...    ...            ...                  ...
# 360      116-439-102   6708         100001                    1
# 361      849-981-514   8500         100000                    2
# 362      726-686-279   9455         100006                    2
# 363      551-937-380    475         100002                    1
# 364      976-542-770   7364         100009                    1
#
#         Transaction Date Bank
# 0    20/03/2023 00:00:00  DTB
# 1    15/11/2023 00:00:00   DS
# 2    14/07/2023 00:00:00  DSB
# 3    18/08/2023 00:00:00   DS
# 4    26/08/2023 00:00:00  DSB
# ..                   ...  ...
# 360  29/01/2023 00:00:00  DTB
# 361  29/10/2023 00:00:00   DS
# 362  10/08/2023 00:00:00   DS
# 363  11/10/2023 00:00:00   DS
# 364  09/10/2023 00:00:00   DS
#
# [365 rows x 6 columns]

# %% [markdown]
# ## Task 2: Rename Online/Inperson
# -----
# - Rename the values in the Online or In-person field, Online of the 1 values and In-Person for the 2 values.
#
# To do this task we can use the map function on the specific column.
# We use a dictionary for the mapping with the key being the original value and the value being the new/ updated version.

# %%
df["Online or In-Person"] = df['Online or In-Person'].map({1:"Online", 2: "In-Person"})
df
# Out:
#     Transaction Code  Value  Customer Code Online or In-Person  \
# 0        716-679-576   1448         100001           In-Person
# 1        795-814-303   7839         100001           In-Person
# 2        807-592-406   5520         100005              Online
# 3        367-545-264   7957         100007           In-Person
# 4        474-374-857   5375         100000           In-Person
# ..               ...    ...            ...                 ...
# 360      116-439-102   6708         100001              Online
# 361      849-981-514   8500         100000           In-Person
# 362      726-686-279   9455         100006           In-Person
# 363      551-937-380    475         100002              Online
# 364      976-542-770   7364         100009              Online
#
#         Transaction Date Bank
# 0    20/03/2023 00:00:00  DTB
# 1    15/11/2023 00:00:00   DS
# 2    14/07/2023 00:00:00  DSB
# 3    18/08/2023 00:00:00   DS
# 4    26/08/2023 00:00:00  DSB
# ..                   ...  ...
# 360  29/01/2023 00:00:00  DTB
# 361  29/10/2023 00:00:00   DS
# 362  10/08/2023 00:00:00   DS
# 363  11/10/2023 00:00:00   DS
# 364  09/10/2023 00:00:00   DS
#
# [365 rows x 6 columns]

# %% [markdown]
# ## Task 3: Changing to day of the week
# -----
# - Change the date to be the day of the week
#
# I did this by the following steps:
#
# - Splitting the date column as the time value is not required.
# - Putting the first of the new columns created by that in place of the transaction dat column.
# - Then I could convert the column into a datetime datatype and use the dt.day_name() so that we could convert the dates to day names.

# %%
datecols = df['Transaction Date'].str.split(" ", n=1, expand=True)
df['Transaction Date'] = datecols[0]
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], format="%d/%m/%Y")
df
# Out:
#     Transaction Code  Value  Customer Code Online or In-Person  \
# 0        716-679-576   1448         100001           In-Person
# 1        795-814-303   7839         100001           In-Person
# 2        807-592-406   5520         100005              Online
# 3        367-545-264   7957         100007           In-Person
# 4        474-374-857   5375         100000           In-Person
# ..               ...    ...            ...                 ...
# 360      116-439-102   6708         100001              Online
# 361      849-981-514   8500         100000           In-Person
# 362      726-686-279   9455         100006           In-Person
# 363      551-937-380    475         100002              Online
# 364      976-542-770   7364         100009              Online
#
#     Transaction Date Bank
# 0         2023-03-20  DTB
# 1         2023-11-15   DS
# 2         2023-07-14  DSB
# 3         2023-08-18   DS
# 4         2023-08-26  DSB
# ..               ...  ...
# 360       2023-01-29  DTB
# 361       2023-10-29   DS
# 362       2023-08-10   DS
# 363       2023-10-11   DS
# 364       2023-10-09   DS
#
# [365 rows x 6 columns]

# %%
df['Transaction Date'] = df['Transaction Date'].dt.day_name()

# %%
df
# Out:
#     Transaction Code  Value  Customer Code Online or In-Person  \
# 0        716-679-576   1448         100001           In-Person
# 1        795-814-303   7839         100001           In-Person
# 2        807-592-406   5520         100005              Online
# 3        367-545-264   7957         100007           In-Person
# 4        474-374-857   5375         100000           In-Person
# ..               ...    ...            ...                 ...
# 360      116-439-102   6708         100001              Online
# 361      849-981-514   8500         100000           In-Person
# 362      726-686-279   9455         100006           In-Person
# 363      551-937-380    475         100002              Online
# 364      976-542-770   7364         100009              Online
#
#     Transaction Date Bank
# 0             Monday  DTB
# 1          Wednesday   DS
# 2             Friday  DSB
# 3             Friday   DS
# 4           Saturday  DSB
# ..               ...  ...
# 360           Sunday  DTB
# 361           Sunday   DS
# 362         Thursday   DS
# 363        Wednesday   DS
# 364           Monday   DS
#
# [365 rows x 6 columns]

# %% [markdown]
# ## Final Outputs
# ------

# %% [markdown]
# ### Total Values of Transactions by each bank
#
# Must contain 2 data fields and 3 rows of data.

# %%
output1 = df.groupby(['Bank']).sum().filter(['Value'])
output1
# Out:
# <ipython-input-26-11b2cbc9730b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   output1 = df.groupby(['Bank']).sum().filter(['Value'])
#        Value
# Bank
# DS    653940
# DSB   530489
# DTB   618238

# %% [markdown]
# ### Total Values by Bank, Day of the Week and Type of Transaction

# %%
output2 = df.groupby(['Bank', 'Transaction Date', 'Online or In-Person']).sum().filter(['Value'])
output2
# Out:
# <ipython-input-34-9a9aaa52b656>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   output2 = df.groupby(['Bank', 'Transaction Date', 'Online or In-Person']).sum().filter(['Value'])
#                                            Value
# Bank Transaction Date Online or In-Person
# DS   Friday           In-Person            58599
#                       Online               58731
#      Monday           In-Person            42806
#                       Online               33563
#      Saturday         In-Person            34867
#                       Online               71357
#      Sunday           In-Person            51301
#                       Online               21761
#      Thursday         In-Person            75582
#                       Online               13337
#      Tuesday          In-Person            32607
#                       Online               36639
#      Wednesday        In-Person            63686
#                       Online               59104
# DSB  Friday           In-Person             9402
#                       Online               45647
#      Monday           In-Person            43546
#                       Online               31692
#      Saturday         In-Person            72679
#                       Online               61350
#      Sunday           In-Person            37755
#                       Online               13086
#      Thursday         In-Person            37567
#                       Online               33463
#      Tuesday          In-Person            28604
#                       Online               32257
#      Wednesday        In-Person            36069
#                       Online               47372
# DTB  Friday           In-Person            41861
#                       Online               27366
#      Monday           In-Person            21561
#                       Online               38688
#      Saturday         In-Person            66334
#                       Online               21392
#      Sunday           In-Person            29468
#                       Online               49087
#      Thursday         In-Person            57605
#                       Online               53756
#      Tuesday          In-Person            54029
#                       Online               68959
#      Wednesday        In-Person            52819
#                       Online               35313

# %%
output2.shape
# Out:
# (42, 1)

# %% [markdown]
# ### Total Values by Bank and Customer Code
# -----

# %%
output3 = df.groupby(['Bank', 'Customer Code']).sum().filter(['Value'])
output3
# Out:
# <ipython-input-38-e6279d1efd39>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   output3 = df.groupby(['Bank', 'Customer Code']).sum().filter(['Value'])
#                     Value
# Bank Customer Code
# DS   100000         57909
#      100001         53063
#      100002         69803
#      100003         25482
#      100004         63315
#      100005         39668
#      100006         77636
#      100007         76190
#      100008         56400
#      100009         56581
#      100010         77893
# DSB  100000         27585
#      100001         67856
#      100002         27936
#      100003         58154
#      100004         39003
#      100005         56396
#      100006         32333
#      100007         29702
#      100008         47121
#      100009         51749
#      100010         92654
# DTB  100000         77252
#      100001         60675
#      100002         48616
#      100003         84574
#      100004         44435
#      100005         37795
#      100006         41909
#      100007         29308
#      100008         69352
#      100009         52926
#      100010         71396

# %%
output3.shape
# Out:
# (33, 1)
